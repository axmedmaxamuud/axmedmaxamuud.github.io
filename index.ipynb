# %% [raw]
# ---
# title: "Ahmed Mohamoud"
# image: axmed.jpg
# about:
#   template: trestles
#   image-width: 20em
#   image-shape: round
#   links:
#     - icon: linkedin
#       text: linkedin
#       href: https://www.linkedin.com/in/ahmed-mahamoud-8949121a1/
#     - icon: github
#       text: Github
#       href: https://github.com/axmedmaxamuud
# ---

# %% [markdown]
# ```{js}
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-34D8XG2PNV"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-34D8XG2PNV');
# </script>
# ```
#
#
#
# ## About Me
#
# As an experienced GIS/Data professional with a diverse background in the humanitarian sector, I excel in ArcGIS Pro, QGIS, R, Python, PowerBI, Tableau, MS Excel, SPSS, Adobe Suite, and ODK. My specialization lies in research design, data collection, interpretation, and visualization.
#
# ## Education
#
# MSc in Research, Statistics & Data Analytics | 2019 - Present
# Amoud University | Hargeisa, Somaliland
#
# MBA in Project Planning & Management | 2018 - 2019
# Admas University | Hargeisa, Somaliland
#
# BA. Development Studies | 2013 - 2016
# Admas University | Hargeisa, Somaliland
#
# ## Experience
#
# <div class="experience">
#   <span class="company">WFP</span> | <span class="job-title">Programme Associate (Data Management)</span>
#   <span class="date">Nov 2022 - Apr 2024</span>
# </div>
#
# <div class="experience">
#   <span class="company">REACH Initiative</span> | <span class="job-title">GIS & Data Specialist</span>
#   <span class="date">Mar 2022 - Oct 2022</span>
# </div>
#
# <div class="experience">
#   <span class="company">REACH Initiative</span> | <span class="job-title">Senior Database Officer</span>
#   <span class="date">Jan 2019 - Feb 2022</span>
# </div>
#
# <div class="experience">
#   <span class="company">SOLNARDO</span> | <span class="job-title">Monitoring & Evaluation Officer</span>
#   <span class="date">Jan 2014 - Dec 2018</span>
# </div>
